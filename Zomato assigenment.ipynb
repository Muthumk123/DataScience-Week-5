# %%
#pip install plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %%
dataset=pd.read_csv("Zomato_Mumbai_Dataset.csv",delimiter='|')

# %%
dataset.isnull().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# CITY                  1
# REGION                1
# URL                   1
# PAGE NO               1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
dataset.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#      CITY                                             REGION  \
# 0  Mumbai  First International Financial Centre-- Bandra ...
# 1  Mumbai                                              Mahim
# 2  Mumbai                                               Juhu
# 3  Mumbai                               Bandra Kurla Complex
# 4  Mumbai                               Bandra Kurla Complex
#
#                                                  URL PAGE NO     CUSINE TYPE  \
# 0  https://www.zomato.com/mumbai/hitchki-bandra-k...       1   Casual Dining
# 1  https://www.zomato.com/mumbai/baba-falooda-mah...       1  Dessert Parlor
# 2  https://www.zomato.com/mumbai/chin-chin-chu-ju...       1   Casual Dining
# 3  https://www.zomato.com/mumbai/butterfly-high-b...       1             Bar
# 4  https://www.zomato.com/mumbai/bkc-dive-bandra-...       1             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %% [markdown]
# # 4. Cleaning the Dataset
# # a. Removing the redundunt rows of data

# %%
wrong_data= dataset['PAGE NO']=='PAGE NO'
dataset[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# 15     TIMING  RATING_TYPE  RATING  VOTES
# 31     TIMING  RATING_TYPE  RATING  VOTES
# 47     TIMING  RATING_TYPE  RATING  VOTES
# 63     TIMING  RATING_TYPE  RATING  VOTES
# 79     TIMING  RATING_TYPE  RATING  VOTES
# ...       ...          ...     ...    ...
# 15000  TIMING  RATING_TYPE  RATING  VOTES
# 15016  TIMING  RATING_TYPE  RATING  VOTES
# 15032  TIMING  RATING_TYPE  RATING  VOTES
# 15048  TIMING  RATING_TYPE  RATING  VOTES
# 15064  TIMING  RATING_TYPE  RATING  VOTES
#
# [942 rows x 12 columns]

# %%
## Performing Negation of the wrong dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe
dataset=dataset[~wrong_data]

# %%
# Dropping columns which are not required for further analysis
dataset.drop(['URL', 'PAGE NO', 'CITY'], axis = 1, inplace=True)

# %%
dataset.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %% [markdown]
# # b. Removing the Null Records

# %%
dataset.isnull().sum()
# Out:
# NAME                  0
# PRICE                 1
# CUSINE_CATEGORY       2
# REGION                1
# CUSINE TYPE           1
# TIMING               66
# RATING_TYPE        1011
# RATING                1
# VOTES                 1
# dtype: int64

# %%
# Checking for a null row
dataset[dataset['PRICE'].isnull()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES
# 15080   NaN

# %%
# Droping the above row from the dataset
dataset=dataset.drop(labels=15080, axis=0)

# %%
# Replacing the other null records with NA
dataset.fillna('NA',inplace=True)

# %%
dataset.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %%
dataset
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075    Tirupati Balaji   500
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# 15077                                 Fast Food,Lebanese
# 15078                                 Desserts,Ice Cream
# 15079                              Desserts,Chinese,Thai
#
#                                                   REGION     CUSINE TYPE  \
# 0      First International Financial Centre-- Bandra ...   Casual Dining
# 1                                                  Mahim  Dessert Parlor
# 2                                                   Juhu   Casual Dining
# 3                                   Bandra Kurla Complex             Bar
# 4                                   Bandra Kurla Complex             Bar
# ...                                                  ...             ...
# 15075                            Oshiwara-- Andheri West   Casual Dining
# 15076                                     Kandivali West     Quick Bites
# 15077                                        Lower Parel            none
# 15078                                     Kandivali West  Dessert Parlor
# 15079                                         Malad West            none
#
#                                               TIMING  RATING_TYPE RATING VOTES
# 0                           12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1                                2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2                             12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3                           12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4                             1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995
# ...                                              ...          ...    ...   ...
# 15075       8am to 11pm,12midnight to 115am(Mon-Sun)         Good    3.5   267
# 15076                         11am to 230am(Mon-Sun)         Good    3.7    64
# 15077  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...      Average    3.4    99
# 15078                         9am to 1230AM(Mon-Sun)         Good    3.5    29
# 15079            12noon to 330pm,7pm to 1am(Mon-Sun)         Good    3.7   121
#
# [14138 rows x 9 columns]

# %% [markdown]
# # c. Converting the DataTypes of numerical columns to numeric dataype

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['RATING'].value_counts()
# Out:
# RATING
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 4.8           4
# 2.2           4
# 4.9           2
# 1.8           1
# 2.0           1
# Name: count, dtype: int64

# %%
# Replacing the text values with '0'
dataset['RATING'].replace(to_replace=['-','NEW','Opening'], value='0', inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\2352873554.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['VOTES'].value_counts()
# Out:
# VOTES
# -       2360
# NEW      953
# 4        364
# 5        320
# 6        288
#         ...
# 1876       1
# 2797       1
# 799        1
# 3058       1
# 3529       1
# Name: count, Length: 1123, dtype: int64

# %%
# Replacing the text values with '0'
dataset['VOTES'].replace(to_replace=['-','NEW','Opening'], value='0', inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\2396252053.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Changing Data Type of the numerical columns
dataset['PRICE'] = dataset['PRICE'].astype('int64')
dataset['RATING'] = dataset['RATING'].astype('float64')
dataset['VOTES'] = dataset['VOTES'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# # d. Working with 'Timing' column

# %%
dataset['TIMING'].value_counts()
# Out:
# TIMING
# 11am to 11pm(Mon-Sun)                           1192
# 11am to 12midnight(Mon-Sun)                      632
# 12noon to 12midnight(Mon-Sun)                    467
# 11am to 1130pm(Mon-Sun)                          309
# 10am to 10pm(Mon-Sun)                            267
#                                                 ...
# 12noon to 4am(Mon-Sat),9am to 4am(Sun)             1
# 1230pm to 11pm(Mon-Thu),1230pm to 1130pm...        1
# 830am to 9pm(Mon-Sat),Closed(Sun)                  1
# 10am to 5pm,7pm to 2am(Mon-Sun)                    1
# 8am to 11am,12noon to 3pm,730pm to 1130pm...       1
# Name: count, Length: 2551, dtype: int64

# %%
 # Splitting the column and storing it in temp_df dataframe
temp_df=dataset['TIMING'].str.split("(",n=1,expand=True)
temp_df
# Out:
#                                      0                                 1
# 0                      12noon to 130am                          Mon-Sun)
# 1                           2pm to 1am                          Mon-Sun)
# 2                        12noon to 1am                          Mon-Sun)
# 3                      12noon to 130am                          Mon-Sun)
# 4                        1130am to 1am                          Mon-Sun)
# ...                                ...                               ...
# 15075  8am to 11pm,12midnight to 115am                          Mon-Sun)
# 15076                    11am to 230am                          Mon-Sun)
# 15077                     11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078                    9am to 1230AM                          Mon-Sun)
# 15079       12noon to 330pm,7pm to 1am                          Mon-Sun)
#
# [14138 rows x 2 columns]

# %%
# Assigning the columns back to the raw_df dataframe
dataset['TIMTNG']=temp_df[0]
dataset['DAYS_OPEN']=temp_df[1]
dataset.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE  RATING  VOTES           TIMTNG  \
# 0  12noon to 130am(Mon-Sun)    Excellent     4.9   3529  12noon to 130am
# 1       2pm to 1am(Mon-Sun)    Very Good     4.4   1723       2pm to 1am
# 2    12noon to 1am(Mon-Sun)    Very Good     4.2    337    12noon to 1am
# 3  12noon to 130am(Mon-Sun)    Very Good     4.3   1200  12noon to 130am
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré     4.4   5995    1130am to 1am
#
#   DAYS_OPEN
# 0  Mon-Sun)
# 1  Mon-Sun)
# 2  Mon-Sun)
# 3  Mon-Sun)
# 4  Mon-Sun)

# %%
# Removing the bracket character from Days column
dataset['DAYS_OPEN'] =dataset['DAYS_OPEN'].str.replace('','',regex=True)
dataset.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE  RATING  VOTES           TIMTNG  \
# 0  12noon to 130am(Mon-Sun)    Excellent     4.9   3529  12noon to 130am
# 1       2pm to 1am(Mon-Sun)    Very Good     4.4   1723       2pm to 1am
# 2    12noon to 1am(Mon-Sun)    Very Good     4.2    337    12noon to 1am
# 3  12noon to 130am(Mon-Sun)    Very Good     4.3   1200  12noon to 130am
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré     4.4   5995    1130am to 1am
#
#   DAYS_OPEN
# 0  Mon-Sun)
# 1  Mon-Sun)
# 2  Mon-Sun)
# 3  Mon-Sun)
# 4  Mon-Sun)

# %%
# Checking for Null records in DAYS_OPEN column
dataset.isnull().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# TIMTNG               0
# DAYS_OPEN          160
# dtype: int64

# %%
#Replacing the Null values with 'NA'
dataset.fillna('NA', inplace=True)

# %%
# Checking info of all the columns
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14138 entries, 0 to 15079
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             14138 non-null  object
#  1   PRICE            14138 non-null  int64
#  2   CUSINE_CATEGORY  14138 non-null  object
#  3   REGION           14138 non-null  object
#  4   CUSINE TYPE      14138 non-null  object
#  5   TIMING           14138 non-null  object
#  6   RATING_TYPE      14138 non-null  object
#  7   RATING           14138 non-null  float64
#  8   VOTES            14138 non-null  int64
#  9   TIMTNG           14138 non-null  object
#  10  DAYS_OPEN        14138 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# # e. Removing the restaurant records whose Rating or Votes is 0

# %%
# Finding those restaurant whose has 0 Rating or Votes
useless_data = (dataset['RATING'] == 0.0) | (dataset['VOTES'] == 0)
dataset[useless_data]
# Out:
#                                 NAME  PRICE  \
# 32     Hotel Annapoorna Refreshments    400
# 34                         Biryani 9    600
# 36                 D Fusion Flavours    350
# 39                      Nation Tadka    400
# 83              Link  Way Restaurant    500
# ...                              ...    ...
# 14998                  Foodies House      0
# 14999                       Khansama      0
# 15010        Earth Cafe @ Waterfield    800
# 15023           How About Some Cream    200
# 15046          Food And Taste Theory    800
#
#                                    CUSINE_CATEGORY  \
# 32                   Maharashtrian,Mughlai,Chinese
# 34                            Biryani,North Indian
# 36                                         Chinese
# 39     North Indian,South Indian,Chinese,Fast Food
# 83                            North Indian,Chinese
# ...                                            ...
# 14998                                      Chinese
# 14999                                      Biryani
# 15010    Cafe,Healthy Food,Italian,Pizza,Beverages
# 15023                                    Beverages
# 15046                          Continental,Italian
#
#                            REGION    CUSINE TYPE  \
# 32                       Ghansoli    Quick Bites
# 34      Near Andheri East Station           none
# 36                  Goregaon East           none
# 39                          Worli           none
# 83                     Jogeshwari    Quick Bites
# ...                           ...            ...
# 14998               Goregaon East           none
# 14999                 Lower Parel           none
# 15010  Linking Road-- Bandra West           Café
# 15023              Mumbai Central  Beverage Shop
# 15046  Phoenix Marketcity-- Kurla  Casual Dining
#
#                                                   TIMING RATING_TYPE  RATING  \
# 32                             1030am to 1230AM(Mon-Sun)   Not rated     0.0
# 34                                  11am to 3am(Mon-Sun)          NA     0.0
# 36                   12noon to 330pm,7pm to 3am(Mon-Sun)          NA     0.0
# 39                             12noon to 1230AM(Mon-Sun)   Not rated     0.0
# 83                     12noon to 4pm,8pm to 1am(Mon-Sun)   Not rated     0.0
# ...                                                  ...         ...     ...
# 14998                             12noon to 4am(Mon-Sun)          NA     0.0
# 14999                             12noon to 3am(Mon-Sun)          NA     0.0
# 15010        10am to 10pm(Mon-Thu),10am to 11pm(Fri-Sun)          NA     0.0
# 15023                             12noon to 3am(Mon-Sun)          NA     0.0
# 15046  9am to 12midnight(Mon-Fri),9am to 1230AM(Sat-Sun)          NA     0.0
#
#        VOTES                      TIMTNG                        DAYS_OPEN
# 32         0            1030am to 1230AM                         Mon-Sun)
# 34         0                 11am to 3am                         Mon-Sun)
# 36         0  12noon to 330pm,7pm to 3am                         Mon-Sun)
# 39         0            12noon to 1230AM                         Mon-Sun)
# 83         0    12noon to 4pm,8pm to 1am                         Mon-Sun)
# ...      ...                         ...                              ...
# 14998      0               12noon to 4am                         Mon-Sun)
# 14999      0               12noon to 3am                         Mon-Sun)
# 15010      0                10am to 10pm   Mon-Thu),10am to 11pm(Fri-Sun)
# 15023      0               12noon to 3am                         Mon-Sun)
# 15046      0           9am to 12midnight  Mon-Fri),9am to 1230AM(Sat-Sun)
#
# [3371 rows x 11 columns]

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe
dataset =dataset[~useless_data]

# %%
# Checking the unique values in the column
dataset['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average          5111
# Good             4330
# Very Good        1137
# Excellent          95
# Poor               47
# Veľmi dobré         6
# Skvělá volba        4
# Dobrze              4
# Bardzo dobrze       3
# İyi                 2
# Buono               2
# Bom                 2
# Muito Bom           2
# Promedio            2
# Dobré               2
# Priemer             2
# Průměr              2
# Ortalama            2
# Bueno               2
# Excelente           1
# Velmi dobré         1
# Baik                1
# Çok iyi             1
# Skvělé              1
# Média               1
# Sangat Baik         1
# Biasa               1
# Muy Bueno           1
# Media               1
# Name: count, dtype: int64

# %%
# Translating the texts into proper English text
dataset['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good',inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good',inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)
dataset['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:3: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\818698782.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Checking all the values correctly mapped
dataset['RATING_TYPE'].value_counts()
# Out:
# RATING_TYPE
# Average      5115
# Good         4347
# Very Good    1148
# Excellent      96
# Poor           57
# Very Poor       4
# Name: count, dtype: int64

# %% [markdown]
# # g. Working on 'REGION' Column

# %%
dataset['REGION'].value_counts()
# Out:
# REGION
# Mira Road                            405
# Malad West                           308
# Chembur                              277
# Kharghar                             268
# Borivali West                        264
#                                     ...
# Little World Mall-- Kharghar           1
# Le Sutra Hotel-- Khar                  1
# Maxus Mall-- Bhayandar                 1
# Orchard Mall-- Goregaon East           1
# Hotel Satkar Residency-- Majiwada      1
# Name: count, Length: 237, dtype: int64

# %%
# Removing the irrelevant text from the Region column
dataset['REGION'] = dataset['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\2425620013.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Removing the West & East from the Region column
dataset['REGION'] = dataset['REGION'].str.replace(' West| west| East| east','',regex=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\1803269033.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset['REGION'].value_counts()
# Out:
# REGION
# Thane                726
# Mira Road            412
# Andheri              409
# Malad                378
# Kandivali            377
#                     ...
# Flea Bazaar Café       3
# Majiwada               3
# Panvel                 2
# CBD Belapur            1
# Girgaon Chowpatty      1
# Name: count, Length: 101, dtype: int64

# %%
 #Replacing Small regions with Known region name
dataset['REGION'] = dataset['REGION'].str.replace('4 Bungalows|7' ,'Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area ',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Runwal Green','Mulund',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Kamothe','Sion',regex=True)
dataset['REGION'] = dataset['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12016\3335051096.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # h. Removing Duplicate records

# %%
# Finding all the duplicate rows
dataset[dataset.duplicated()]
# Out:
#                                 NAME  PRICE  \
# 4064   Sai Sannidhi Restaurant & Bar   1000
# 4068                    Konkan Katta    400
# 4082                  Usmaniya Hotel    600
# 4083                    Gina's Cakes    450
# 4084          Konkanastha Lunch Home    400
# ...                              ...    ...
# 14200      Mezbaan Family Restaurant    350
# 14204               Jyoti Lunch Home    650
# 14253                        On Toes    900
# 14761                    Frosty Farm    400
# 14928               Shree Manu Sagar    300
#
#                             CUSINE_CATEGORY     REGION     CUSINE TYPE  \
# 4064                    North Indian,Konkan    Dahisar   Casual Dining
# 4068          Seafood,Maharashtrian,Malwani   Mahakali     Quick Bites
# 4082                                Mughlai       Fort   Casual Dining
# 4083                                 Bakery  Dombivali            none
# 4084                        Seafood,Malwani    Chakala   Casual Dining
# ...                                     ...        ...             ...
# 14200                       Chinese,Mughlai     Mumbra           Dhaba
# 14204  Chinese,North Indian,Seafood,Mughlai     Mulund   Casual Dining
# 14253          Italian,North Indian,Chinese      Malad   Casual Dining
# 14761          Ice Cream,Desserts,Fast Food      Malad  Dessert Parlor
# 14928           North Indian,Chinese,Indian   Ghansoli     Quick Bites
#
#                                        TIMING RATING_TYPE  RATING  VOTES  \
# 4064              11am to 12midnight(Mon-Sun)        Good     3.7     99
# 4068   11am to 330pm,630pm to 1130pm(Mon-Sun)        Good     3.5    181
# 4082                1030am to 1130pm(Mon-Sun)     Average     3.2      8
# 4083                    11am to 11pm(Mon-Sun)        Good     3.5     49
# 4084   12noon to 3pm,730pm to 1030pm(Mon-Sun)        Good     3.5     44
# ...                                       ...         ...     ...    ...
# 14200               12noon to 1230AM(Mon-Sun)     Average     2.8     97
# 14204                 11am to 1230AM(Mon-Sun)        Good     3.5     49
# 14253    12noon to 3pm,7pm to 1230AM(Mon-Sun)        Good     3.6     76
# 14761                  1pm to 1215AM(Mon-Sun)        Good     3.6    120
# 14928  1130am to 415pm,7pm to 1215AM(Mon-Sun)     Average     3.3     51
#
#                               TIMTNG DAYS_OPEN
# 4064              11am to 12midnight  Mon-Sun)
# 4068   11am to 330pm,630pm to 1130pm  Mon-Sun)
# 4082                1030am to 1130pm  Mon-Sun)
# 4083                    11am to 11pm  Mon-Sun)
# 4084   12noon to 3pm,730pm to 1030pm  Mon-Sun)
# ...                              ...       ...
# 14200               12noon to 1230AM  Mon-Sun)
# 14204                 11am to 1230AM  Mon-Sun)
# 14253    12noon to 3pm,7pm to 1230AM  Mon-Sun)
# 14761                  1pm to 1215AM  Mon-Sun)
# 14928  1130am to 415pm,7pm to 1215AM  Mon-Sun)
#
# [220 rows x 11 columns]

# %%
# Dropping all the duplicate rows
dataset = dataset.drop_duplicates()

# %% [markdown]
# # 4. Copying the cleaned data into a new DataFrame

# %%
zomato_df = dataset.copy()

# %%
zomato_df.head()
# Out:
#              NAME  PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki   1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda    400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu   1800                                      Asian,Chinese
# 3  Butterfly High   1000                                      Modern Indian
# 4       BKC  DIVE   1200                   North Indian,Chinese,Continental
#
#    REGION     CUSINE TYPE                    TIMING RATING_TYPE  RATING  \
# 0  Bandra   Casual Dining  12noon to 130am(Mon-Sun)   Excellent     4.9
# 1   Mahim  Dessert Parlor       2pm to 1am(Mon-Sun)   Very Good     4.4
# 2    Juhu   Casual Dining    12noon to 1am(Mon-Sun)   Very Good     4.2
# 3  Bandra             Bar  12noon to 130am(Mon-Sun)   Very Good     4.3
# 4  Bandra             Bar    1130am to 1am(Mon-Sun)   Very Good     4.4
#
#    VOTES           TIMTNG DAYS_OPEN
# 0   3529  12noon to 130am  Mon-Sun)
# 1   1723       2pm to 1am  Mon-Sun)
# 2    337    12noon to 1am  Mon-Sun)
# 3   1200  12noon to 130am  Mon-Sun)
# 4   5995    1130am to 1am  Mon-Sun)

# %% [markdown]
# # 5. Performing Exploratory Data Analysis
# # Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
fig = px.histogram(zomato_df, x='CUSINE TYPE', color='CUSINE TYPE',
title= 'No. of Restaurants by Cuisine Type',
labels={'CUSINE TYPE':'Cuisine Type'})
fig.show()

# %%
 #pip install --upgrade kaleido

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type_df = zomato_df['RATING_TYPE'].value_counts().reset_index()
rating_type_df.rename(columns={'index':'RATING TYPE', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
rating_type_df
# Out:
#   COUNT OF RESTAURANTS  count
# 0              Average   4983
# 1                 Good   4263
# 2            Very Good   1145
# 3            Excellent     96
# 4                 Poor     56
# 5            Very Poor      4

# %%
fig = px.pie(rating_type_df, names='RATING TYPE', values='COUNT OF RESTAURANTS',color='RATING TYPE',
      title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 fig = px.pie(rating_type_df, names='RATING TYPE', values='COUNT OF RESTAURANTS',color='RATING TYPE',
#       2       title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
#       3 fig.show()
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\plotly\express\_chart_types.py:1721, in pie(data_frame, names, values, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, category_orders, labels, title, subtitle, template, width, height, opacity, hole)
#    1719 else:
#    1720     layout_patch = {}
# -> 1721 return make_figure(
#    1722     args=locals(),
#    1723     constructor=go.Pie,
#    1724     trace_patch=dict(showlegend=(names is not None), hole=hole),
#    1725     layout_patch=layout_patch,
#    1726 )
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\plotly\express\_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\plotly\express\_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\plotly\express\_core.py:1358, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1356         if argument == "index":
#    1357             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1358         raise ValueError(err_msg)
#    1359 elif length and (actual_len := len(df_input)) != length:
#    1360     raise ValueError(
#    1361         "All arguments should have the same length. "
#    1362         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1369         )
#    1370     )
#
# ValueError: Value of 'names' is not the name of a column in 'data_frame'. Expected one of ['COUNT OF RESTAURANTS', 'count'] but received: RATING TYPE

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?

# %%
seafood_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                           NAME  PRICE  \
# 7104                                Thangabali   1000
# 76                     Ceremonial Kitchen & Co   1000
# 13685                   Maharashtra Lunch Home    600
# 9954                        Pi Bar and Kitchen   1600
# 884        Rajmanya- Seafood family restaurant    800
# 12433                          Quarter Canteen   1100
# 3380                                 Peco Peco    700
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
# 915                   Monis Bar and Restaurant   1000
# 8890                            Hardeep Punjab   1100
#
#                                          CUSINE_CATEGORY    REGION  \
# 7104      Seafood,South Indian,Mangalorean,Andhra,Kerala      Khar
# 76            Seafood,Maharashtrian,North Indian,Chinese     Thane
# 13685               Maharashtrian,Malwani,Konkan,Seafood  Kharghar
# 9954   Continental,European,Italian,Seafood,Pizza,Des...   Andheri
# 884                         Maharashtrian,Konkan,Seafood     Vashi
# 12433                       North Indian,Seafood,Chinese    Bandra
# 3380                               Chinese,Seafood,Asian     Powai
# 902                                    Seafood,Beverages    Bandra
# 915    North Indian,Chinese,Continental,Seafood,Bever...     Thane
# 8890                North Indian,Chinese,Mughlai,Seafood      Sion
#
#          CUSINE TYPE                                    TIMING RATING_TYPE  \
# 7104             Bar         12noon to 4pm,7pm to 3am(Mon-Sun)   Excellent
# 76     Casual Dining                 1130am to 1130pm(Mon-Sun)   Excellent
# 13685  Casual Dining      11am to 345pm,7pm to 1145pm(Mon-Sun)   Excellent
# 9954             Bar  12noon to 6pm,7pm to 12midnight(Mon-Sun)   Excellent
# 884    Casual Dining                     11am to 11pm(Mon-Sun)   Excellent
# 12433  Casual Dining       12noon to 330pm,7pm to 1am(Mon-Sun)   Excellent
# 3380            none    12noon to 330pm,7pm to 1230AM(Mon-Sun)   Excellent
# 902    Casual Dining                    12noon to 1am(Mon-Sun)   Excellent
# 915    Casual Dining    1130am to 330pm,6pm to 1130pm(Mon-Sun)   Very Good
# 8890   Casual Dining                      11am to 1am(Mon-Sun)   Very Good
#
#        RATING  VOTES                           TIMTNG DAYS_OPEN
# 7104      4.7    564         12noon to 4pm,7pm to 3am  Mon-Sun)
# 76        4.6    350                 1130am to 1130pm  Mon-Sun)
# 13685     4.6    209      11am to 345pm,7pm to 1145pm  Mon-Sun)
# 9954      4.5   2068  12noon to 6pm,7pm to 12midnight  Mon-Sun)
# 884       4.5    178                     11am to 11pm  Mon-Sun)
# 12433     4.5    573       12noon to 330pm,7pm to 1am  Mon-Sun)
# 3380      4.5    497    12noon to 330pm,7pm to 1230AM  Mon-Sun)
# 902       4.5    100                    12noon to 1am  Mon-Sun)
# 915       4.4    662    1130am to 330pm,6pm to 1130pm  Mon-Sun)
# 8890      4.4    871                      11am to 1am  Mon-Sun)

# %% [markdown]
# # Q4) Which is the best Food Truck in Mumbai?

# %%
foodtruck_df = zomato_df[zomato_df['CUSINE TYPE'] == 'Food Truck']
foodtruck_df.sort_values(by='RATING',ascending=False).head(2)
# Out:
#                    NAME  PRICE    CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 262   Dumpling Delights    200              Momos  Matunga  Food Truck
# 1017    Street Food Co.    250  Fast Food,Chinese    Virar  Food Truck
#
#                        TIMING RATING_TYPE  RATING  VOTES          TIMTNG  \
# 262   430pm to 930pm(Mon-Sun)   Very Good     4.3    212  430pm to 930pm
# 1017      6pm to 3am(Mon-Sun)   Very Good     4.1    274      6pm to 3am
#
#      DAYS_OPEN
# 262   Mon-Sun)
# 1017  Mon-Sun)

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Mumbai?

# %%
# Assuming restaurants having rating above 4.5
highest_rated_df = zomato_df[zomato_df['RATING'] >= 4.5]
highest_rated_df
# Out:
#                              NAME  PRICE  \
# 0                         Hitchki   1200
# 6                  Persian Darbar   1300
# 7                         Tanatan   1500
# 9              Plum by Bent Chair   1800
# 10                  Angrezi Dhaba   1500
# ...                           ...    ...
# 14228  Zaika Crave - Club Aquaria   1300
# 14234                Cone Culture    250
# 15007                  Dessertino    300
# 15051                    Tick-eat    800
# 15056             Daftar Goregaon    750
#
#                                          CUSINE_CATEGORY       REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...       Bandra
# 6                   Biryani,North Indian,Chinese,Mughlai        Marol
# 7                                          Modern Indian         Juhu
# 9                                                  Asian  Lower Parel
# 10                    North Indian,Chinese,Thai,European        Dadar
# ...                                                  ...          ...
# 14228          North Indian,Continental,Chinese,Desserts     Borivali
# 14234                                           European     Kharghar
# 15007                                 Desserts,Ice Cream    Kandivali
# 15051      North Indian,Italian,Chinese,Mexican,Lebanese       Mulund
# 15056               Pizza,Chinese,North Indian,Beverages     Goregaon
#
#           CUSINE TYPE                                      TIMING RATING_TYPE  \
# 0       Casual Dining                    12noon to 130am(Mon-Sun)   Excellent
# 6       Casual Dining                        10am to 3am(Mon-Sun)   Excellent
# 7       Casual Dining                    12noon to 130am(Mon-Sun)   Excellent
# 9       Casual Dining                      12noon to 1am(Mon-Sun)   Excellent
# 10                Bar                      12noon to 1am(Mon-Sun)   Excellent
# ...               ...                                         ...         ...
# 14228   Casual Dining  11am to 330pm,7pm to 1130pm(Mon,Tue,Wed...   Excellent
# 14234   Casual Dining         Closed(Mon),12noon to 11pm(Tue-Sun)   Excellent
# 15007  Dessert Parlor                 11am to 12midnight(Mon-Sun)   Excellent
# 15051   Casual Dining      1130am to 330pm,7pm to 1130pm(Mon-Sun)   Excellent
# 15056   Casual Dining                   12noon to 1130pm(Mon-Sun)   Excellent
#
#        RATING  VOTES                         TIMTNG  \
# 0         4.9   3529                12noon to 130am
# 6         4.5   3058                    10am to 3am
# 7         4.7   1842                12noon to 130am
# 9         4.7   1876                  12noon to 1am
# 10        4.5   2092                  12noon to 1am
# ...       ...    ...                            ...
# 14228     4.5   1302    11am to 330pm,7pm to 1130pm
# 14234     4.6    492                         Closed
# 15007     4.8    184             11am to 12midnight
# 15051     4.5    754  1130am to 330pm,7pm to 1130pm
# 15056     4.6    388               12noon to 1130pm
#
#                           DAYS_OPEN
# 0                          Mon-Sun)
# 6                          Mon-Sun)
# 7                          Mon-Sun)
# 9                          Mon-Sun)
# 10                         Mon-Sun)
# ...                             ...
# 14228                Mon,Tue,Wed...
# 14234  Mon),12noon to 11pm(Tue-Sun)
# 15007                      Mon-Sun)
# 15051                      Mon-Sun)
# 15056                      Mon-Sun)
#
# [97 rows x 11 columns]

# %%
fig = px.histogram(highest_rated_df, x='REGION', color='CUSINE TYPE',
      title= 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['REGION', 'CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#     REGION     CUSINE TYPE   PRICE
# 0  Andheri             Bar  1600.0
# 1  Andheri            Café   800.0
# 2  Andheri   Casual Dining  1212.5
# 3  Andheri  Dessert Parlor   300.0
# 4  Andheri          Lounge  1700.0

# %%
fig = px.scatter(highest_rated_price_df, x="REGION", y="PRICE", color="CUSINE TYPE", symbol="CUSINE TYPE",
title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df
# Out:
#                     NAME  PRICE  \
# 0                Hitchki   1200
# 2          Chin Chin Chu   1800
# 4              BKC  DIVE   1200
# 5       Flea Bazaar Café    800
# 6         Persian Darbar   1300
# ...                  ...    ...
# 15071      Lucknow Zaika    500
# 15072     Zuha's Kitchen    400
# 15075    Tirupati Balaji    500
# 15076  Hari Om Snack Bar    350
# 15079     Mandarin Panda    400
#
#                                          CUSINE_CATEGORY          REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...          Bandra
# 2                                          Asian,Chinese            Juhu
# 4                       North Indian,Chinese,Continental          Bandra
# 5      American,Asian,Street Food,North Indian,Luckno...     Lower Parel
# 6                   Biryani,North Indian,Chinese,Mughlai           Marol
# ...                                                  ...             ...
# 15071                               North Indian,Chinese           Kurla
# 15072                       Chinese,North Indian,Mughlai  Mumbai Central
# 15075                     Chinese,Fast Food,North Indian         Andheri
# 15076                     Fast Food,South Indian,Chinese       Kandivali
# 15079                              Desserts,Chinese,Thai           Malad
#
#          CUSINE TYPE                                    TIMING RATING_TYPE  \
# 0      Casual Dining                  12noon to 130am(Mon-Sun)   Excellent
# 2      Casual Dining                    12noon to 1am(Mon-Sun)   Very Good
# 4                Bar                    1130am to 1am(Mon-Sun)   Very Good
# 5               Café                    12noon to 1am(Mon-Sun)   Very Good
# 6      Casual Dining                      10am to 3am(Mon-Sun)   Excellent
# ...              ...                                       ...         ...
# 15071    Quick Bites                    12noon to 2am(Mon-Sun)     Average
# 15072    Quick Bites     12noon to 4pm,730pm to 430am(Mon-Sun)     Average
# 15075  Casual Dining  8am to 11pm,12midnight to 115am(Mon-Sun)        Good
# 15076    Quick Bites                    11am to 230am(Mon-Sun)        Good
# 15079           none       12noon to 330pm,7pm to 1am(Mon-Sun)        Good
#
#        RATING  VOTES                           TIMTNG DAYS_OPEN
# 0         4.9   3529                  12noon to 130am  Mon-Sun)
# 2         4.2    337                    12noon to 1am  Mon-Sun)
# 4         4.4   5995                    1130am to 1am  Mon-Sun)
# 5         4.2   2042                    12noon to 1am  Mon-Sun)
# 6         4.5   3058                      10am to 3am  Mon-Sun)
# ...       ...    ...                              ...       ...
# 15071     2.6     36                    12noon to 2am  Mon-Sun)
# 15072     3.3     13     12noon to 4pm,730pm to 430am  Mon-Sun)
# 15075     3.5    267  8am to 11pm,12midnight to 115am  Mon-Sun)
# 15076     3.7     64                    11am to 230am  Mon-Sun)
# 15079     3.7    121       12noon to 330pm,7pm to 1am  Mon-Sun)
#
# [5119 rows x 11 columns]

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.7  400.000000
# 1        Bakery     2.8  285.714286
# 2        Bakery     2.9  328.571429
# 3        Bakery     3.0  300.000000
# 4        Bakery     3.1  369.117647
# ..          ...     ...         ...
# 278        none     4.3  683.333333
# 279        none     4.4  555.000000
# 280        none     4.5  420.000000
# 281        none     4.6  687.500000
# 282        none     4.7  350.000000
#
# [283 rows x 3 columns]

# %%
fig = px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?

# %%
region_price_df = zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df
# Out:
#                                                REGION       PRICE
# 0                                              Airoli  452.287582
# 1                                             Alibaug  665.000000
# 2                                           Ambernath  514.000000
# 3                                             Andheri  590.049383
# 4   Andheri|Azad Nagar|Near Andheri Station|Veera ...  528.787879
# ..                                                ...         ...
# 80                                           Vikhroli  480.434783
# 81                                         Vile Parle  464.457831
# 82                                              Virar  452.027027
# 83                                             Wadala  427.500000
# 84                                              Worli  537.012987
#
# [85 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x="REGION", y="PRICE").update_traces(marker_size=8)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?
# The criteria for Affordable Restaurants would be:-
# 1) Low Price
# 2) High Rated
# First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our dataframe.
# Let me
# explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# np.float64(1250.0)

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                                                     NAME  PRICE  \
# 6137                                  Sanjog Wine N Dine      5
# 2925                                          Jab We Eat     50
# 9598                                           Ho5 Store     50
# 10996             Pandurang Wada Pav And Sandwich Centre    100
# 3328               Gurukrupa Sandwich And Frankie Corner    100
# ...                                                  ...    ...
# 4                                              BKC  DIVE   1200
# 17                                               Ustaadi   1200
# 7301                                SamBar Pub & Kitchen   1250
# 6045   Fabelle at The Chocolate Boutique - ITC Grand ...   1250
# 964                                         Bijoli Grill   1250
#
#                                          CUSINE_CATEGORY          REGION  \
# 6137                                North Indian,Chinese           Thane
# 2925   South Indian,North Indian,Maharashtrian,Fast Food         Girgaum
# 9598                                           Fast Food         Matunga
# 10996                                        Street Food        Goregaon
# 3328                                     Rolls,Fast Food            Sion
# ...                                                  ...             ...
# 4                       North Indian,Chinese,Continental          Bandra
# 17     Asian,Biryani,Chinese,North Indian,Mughlai,Mid...  Mumbai Central
# 7301               Finger Food,South Indian,North Indian            Khar
# 6045                                            Desserts           Parel
# 964                                              Bengali           Powai
#
#           CUSINE TYPE
# 6137    Casual Dining
# 2925             none
# 9598             none
# 10996     Quick Bites
# 3328             none
# ...               ...
# 4                 Bar
# 17      Casual Dining
# 7301              Pub
# 6045   Dessert Parlor
# 964     Casual Dining
#
# [10190 rows x 5 columns]

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE','RATING']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['RATING'] >= 4.5]
highrate_rest_df.sort_values(by='PRICE', inplace=True)
highrate_rest_df
# Out:
#                                           NAME  PRICE  \
# 1502             Cake Centre-The Dessert Maker    150
# 807                               Moussestruck    200
# 763                     Curry And Combos Twist    200
# 14234                             Cone Culture    250
# 725                                  Belo Pops    300
# ...                                        ...    ...
# 8887                      Drifters Tap Station   2000
# 1786                             Global Fusion   2000
# 5335                                Mia Cucina   2000
# 12625                        House of Mandarin   2100
# 902    The Harbour Bay - SeaFood Kitchen & Bar   2400
#
#                                   CUSINE_CATEGORY                REGION  \
# 1502                                     Desserts     Mohammad Ali Road
# 807                                      Desserts  Near Andheri Station
# 763                          North Indian,Chinese               Andheri
# 14234                                    European              Kharghar
# 725                  Ice Cream,Desserts,Beverages               Andheri
# ...                                           ...                   ...
# 8887   North Indian,Continental,European,American                Bandra
# 1786          Chinese,Japanese,Asian,North Indian                 Worli
# 5335                                      Italian                Bandra
# 12625                         Chinese,Sushi,Asian                Bandra
# 902                             Seafood,Beverages                Bandra
#
#           CUSINE TYPE  RATING
# 1502   Dessert Parlor     4.6
# 807              none     4.5
# 763       Quick Bites     4.5
# 14234   Casual Dining     4.6
# 725              none     4.5
# ...               ...     ...
# 8887    Casual Dining     4.5
# 1786      Fine Dining     4.6
# 5335    Casual Dining     4.5
# 12625   Casual Dining     4.5
# 902     Casual Dining     4.5
#
# [97 rows x 6 columns]

# %% [markdown]
# # Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating
highrate_aff_df

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# # The criteria for most Reliable Restaurants would be:-
# 1) Low Price 2) High Rated 3) Large No. of Votes
# First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['VOTES'].mean()
mean_votes
# Out:
# np.float64(177.2656679624538)

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE', 'VOTES']]
mean_rest_df = mean_rest_df[mean_rest_df['VOTES'] > 177]
mean_rest_df.sort_values(by='VOTES', inplace=True)
mean_rest_df
# Out:
#                                NAME  PRICE  \
# 99             Appetite - Resto Bar    700
# 12267                   Buddha Bowl   1000
# 2193                  Mumbai Darbar    850
# 11211                    Soul Curry    800
# 2392      Jain Sweet & Farsan House    200
# ...                             ...    ...
# 8539             Leopold Cafe & Bar   1600
# 1251                   Joey's Pizza    800
# 5337   Chili's American Grill & Bar   1400
# 3751                   Prithvi Cafe    700
# 8897                        Candies    700
#
#                                     CUSINE_CATEGORY       REGION  \
# 99                             North Indian,Chinese        Powai
# 12267                            Asian,Healthy Food       Bandra
# 2193                   North Indian,Chinese,Seafood  Lower Parel
# 11211  Chinese,North Indian,Malwani,Mughlai,Biryani      Bhandup
# 2392         Street Food,Beverages,Fast Food,Mithai     Goregaon
# ...                                             ...          ...
# 8539               American,Chinese,Mughlai,Italian       Colaba
# 1251                                          Pizza        Malad
# 5337                American,Mexican,Burger,Tex-Mex        Powai
# 3751                                 Cafe,Fast Food         Juhu
# 8897             Cafe,Italian,North Indian,Desserts       Bandra
#
#          CUSINE TYPE  VOTES
# 99     Casual Dining    178
# 12267           none    178
# 2193   Casual Dining    178
# 11211  Casual Dining    178
# 2392     Quick Bites    178
# ...              ...    ...
# 8539   Casual Dining   7327
# 1251     Quick Bites   7350
# 5337   Casual Dining   7377
# 3751            Café   8000
# 8897            Café  10217
#
# [2345 rows x 6 columns]

# %% [markdown]
# # These are the most reliable, highest rated and affordable restaurants:-
# # We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# This dataframe obtained below shows the restaurants whose:
# Cost is below 1250
# Rating is above 4.5
# Votes are above 177

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest_df = reliable_rest_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
reliable_rest_df
# Out:
#                                    NAME  PRICE  \
# 0   Rajmanya- Seafood family restaurant    800
# 1                        Fresh Food Co.    500
# 2                            Dessertino    300
# 3                               Invento   1200
# 4                Maharashtra Lunch Home    600
# 5                              Regano's    600
# 6                       Big Bang Cuurry    350
# 7                           Sandy's Den   1000
# 8                     Angrezi Patiyalaa   1200
# 9                                 Maezo   1000
# 10                         Tossin Pizza    900
# 11                    Little West Pizza    600
# 12              Ceremonial Kitchen & Co   1000
# 13                         Moussestruck    200
# 14                      Daftar Goregaon    750
# 15          Poetry By Love & Cheesecake   1000
# 16                         Makhan Singh    800
# 17                     The Joker Bistro   1200
# 18                         Cone Culture    250
# 19                            Peco Peco    700
# 20           Shuruwat- Veg Food Journey    600
# 21                Justice Cafe and Dine    800
# 22                           Thangabali   1000
# 23                       Harsh's Bistro    800
# 24                      Quarter Canteen   1100
# 25                       Culinary Tales   1200
# 26                          Dum & Curry    700
# 27                        Curry Culture    800
# 28                            Belo Pops    300
# 29                             Tick-eat    800
# 30              Coppetto Artisan Gelato    350
# 31        Zaika Restaurant & Party Hall   1000
# 32                      Shaollin Temple   1000
# 33                       Spice Republic   1200
# 34                  Aquafire Restaurant   1100
# 35                             Rajdhani    950
# 36               Wild Dining Restaurant   1200
# 37                          Family Tree    800
# 38                     Bombay Salad Co.    900
# 39                           Cafe Monza   1000
# 40                              Hitchki   1200
# 41                                Vedge   1000
# 42                         Joey's Pizza    800
#
#                                       CUSINE_CATEGORY  \
# 0                        Maharashtrian,Konkan,Seafood
# 1   Continental,Healthy Food,Salad,Beverages,Desse...
# 2                                  Desserts,Ice Cream
# 3      Chinese,Fast Food,North Indian,Italian,Mexican
# 4                Maharashtrian,Malwani,Konkan,Seafood
# 5              Continental,Fast Food,Italian,Desserts
# 6                          North Indian,Biryani,Rolls
# 7                                  Fast Food,Bar Food
# 8   North Indian,Finger Food,American,Mexican,Chinese
# 9                                       Modern Indian
# 10                            Pizza,Italian,Fast Food
# 11                                              Pizza
# 12         Seafood,Maharashtrian,North Indian,Chinese
# 13                                           Desserts
# 14               Pizza,Chinese,North Indian,Beverages
# 15                                      Cafe,Desserts
# 16                       North Indian,Chinese,Biryani
# 17                   North Indian,Chinese,Continental
# 18                                           European
# 19                              Chinese,Seafood,Asian
# 20  Continental,Tea,South Indian,Fast Food,Pizza,N...
# 21  Cafe,Chinese,Italian,Continental,North Indian,...
# 22     Seafood,South Indian,Mangalorean,Andhra,Kerala
# 23                                Chinese,Continental
# 24                       North Indian,Seafood,Chinese
# 25   Chinese,European,Continental,Salad,Italian,Pizza
# 26                       Mughlai,North Indian,Chinese
# 27   North Indian,Biryani,Chinese,Kebab,Mughlai,Asian
# 28                       Ice Cream,Desserts,Beverages
# 29      North Indian,Italian,Chinese,Mexican,Lebanese
# 30                                 Ice Cream,Desserts
# 31                     North Indian,Chinese,Beverages
# 32                                       Chinese,Thai
# 33  Cafe,Continental,Mediterranean,Mexican,Italian...
# 34           North Indian,Continental,Chinese,Italian
# 35                   Gujarati,Rajasthani,North Indian
# 36           North Indian,Continental,Mexican,Chinese
# 37         Italian,Mexican,North Indian,Chinese,Salad
# 38                          Salad,Healthy Food,Juices
# 39                     Italian,American,Salad,Mexican
# 40  Modern Indian,North Indian,Chinese,Momos,Birya...
# 41    Thai,Chinese,North Indian,Mexican,Italian,Asian
# 42                                              Pizza
#
#                                                REGION     CUSINE TYPE
# 0                                               Vashi   Casual Dining
# 1                                           Santacruz            none
# 2                                           Kandivali  Dessert Parlor
# 3                                         Lower Parel   Casual Dining
# 4                                            Kharghar   Casual Dining
# 5                                               Malad   Casual Dining
# 6   Andheri|Azad Nagar|Near Andheri Station|Veera ...            none
# 7                                             Chembur   Casual Dining
# 8                                             Andheri   Casual Dining
# 9                                               Thane   Casual Dining
# 10                                            Chembur   Casual Dining
# 11                                           Borivali     Quick Bites
# 12                                              Thane   Casual Dining
# 13                               Near Andheri Station            none
# 14                                           Goregaon   Casual Dining
# 15                                               Juhu            Café
# 16                                              Powai            none
# 17                                        CBD Belapur   Casual Dining
# 18                                           Kharghar   Casual Dining
# 19                                              Powai            none
# 20                                          Ghatkopar   Casual Dining
# 21                                              Thane            Café
# 22                                               Khar             Bar
# 23                                              Malad   Casual Dining
# 24                                             Bandra   Casual Dining
# 25                                   Veera Desai Area   Casual Dining
# 26                                              Powai     Quick Bites
# 27                                              Powai            none
# 28                                            Andheri            none
# 29                                             Mulund   Casual Dining
# 30                                             Bandra  Dessert Parlor
# 31                                          Bhayandar   Casual Dining
# 32                                        CBD Belapur   Casual Dining
# 33                                           Borivali            Café
# 34                                         Vile Parle   Casual Dining
# 35                                          Ghatkopar   Casual Dining
# 36                                            Andheri   Casual Dining
# 37                                              Thane   Casual Dining
# 38                                             Bandra   Casual Dining
# 39                                           Kharghar   Casual Dining
# 40                                             Bandra   Casual Dining
# 41                                   Veera Desai Area   Casual Dining
# 42                                              Malad     Quick Bites
